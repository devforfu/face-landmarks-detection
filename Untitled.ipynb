# %% [markdown]
# # Face Landmarks
#
# Using a subset of [UMD Faces](http://umdfaces.io) database to train a face landmarks predicting model.

# %%
from functools import partial
from multiprocessing import Pool
from os.path import join
from pathlib import Path
import random
import math
import sys

# %%
try:
    old_path
except NameError:
    old_path = sys.path
    new_path = [str(Path.cwd()/'loop')] + old_path
    sys.path = new_path

# %%
import pandas as pd
import numpy as np
import cv2 as cv
import PIL.Image
from imageio import imread
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from tqdm import tqdm_notebook as tqdm

import torch

# %%
from loop import train
from loop.config import defaults
from basedir import DATA, META, NUM_LANDMARKS

# %%
SEED = 1
DEVICE = torch.device('cuda:1')
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
defaults.device = DEVICE

# %% [markdown]
# ---
# ## Dataset First Glance

# %%
meta = pd.read_csv(META)
meta.columns = meta.columns.str.lower()
cols = meta.columns
file_cols = ['subject_id', 'file']
face_cols = cols[cols.str.startswith('face')].tolist()
x_cols = cols[cols.str.startswith('p') & cols.str.endswith('x')].tolist()
y_cols = cols[cols.str.startswith('p') & cols.str.endswith('y')].tolist()
faces_df = meta[file_cols + face_cols + x_cols + y_cols]
faces_df.head()
# Out:
#    subject_id                                        file     face_x  \
# 0           1  andrew_j_feustel/andrew_j_feustel_0001.jpg  396.10470
# 1           1  andrew_j_feustel/andrew_j_feustel_0002.jpg  808.97000
# 2           1  andrew_j_feustel/andrew_j_feustel_0003.jpg  116.16960
# 3           1  andrew_j_feustel/andrew_j_feustel_0004.jpg  483.74100
# 4           1  andrew_j_feustel/andrew_j_feustel_0005.jpg   19.08284
#
#       face_y  face_width  face_height       p1x       p2x       p3x       p4x  \
# 0  115.99280    55.28760     53.28240  406.4610  411.5070  417.1110  428.6170
# 1  218.05190    51.22800     49.00920  814.2580  818.2730  823.3880  834.2550
# 2   82.37583    54.30480     56.21364  120.6950  122.2240  125.1790  132.0140
# 3  213.87210   320.85600    313.16280  552.0410  587.0870  625.0260  693.3090
# 4   52.63863    65.63352     64.68804   30.0739   36.4028   43.5955   58.0033
#
#     ...         p12y      p13y      p14y      p15y     p16y      p17y  \
# 0   ...     127.0370  140.5620  138.0710  138.8910  138.602  142.3300
# 1   ...     227.0650  245.2970  239.5190  238.9180  238.428  240.4170
# 2   ...      94.0531  110.1360  109.3490  106.9300  108.483  111.0730
# 3   ...     273.0160  350.0050  345.9300  352.6960  347.401  353.7210
# 4   ...      65.4809   83.2004   79.2413   80.0437   79.606   84.1834
#
#        p18y      p19y     p20y     p21y
# 0  147.6620  149.1460  148.159  164.835
# 1  248.7770  248.6390  246.979  262.977
# 2  119.6780  118.6960  118.978  133.905
# 3  402.4170  410.8210  402.350  500.938
# 4   91.0663   92.6855   91.236  111.936
#
# [5 rows x 48 columns]
